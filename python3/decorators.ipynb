# %%
import time

def time_it(func):
    def wrapper(*args,**kwargs):
        start = time.time()
        result = func(*args,**kwargs)
        end = time.time()
        print(func.__name__ +" took " + str((end-start)*1000) + "mil sec")
        return result
    return wrapper


@time_it
def calc_square(numbers):
    result = []
    for number in numbers:
        result.append(number*number)
    return result


@time_it
def calc_cube(numbers):
    result = []
    for number in numbers:
        result.append(number*number*number)
    return result
    
    
array = range(1,10)
out_square = calc_square(array)
out_cube = calc_cube(array)
print("square of numbers = " ,out_square)
print("cube of numbers = ",out_cube)
# Out:
# calc_square took 0.00762939453125mil sec
# calc_cube took 0.007867813110351562mil sec
# square of numbers =  [1, 4, 9, 16, 25, 36, 49, 64, 81]
# cube of numbers =  [1, 8, 27, 64, 125, 216, 343, 512, 729]
